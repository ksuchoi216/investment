# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
import sys
import os
import torch
import warnings
import yaml
from easydict import EasyDict as edict
from pprint import pprint

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (16, 3)


# in pandas, display 100 rows
pd.set_option('display.max_rows', 100)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import yfinance as yf
from pandas_datareader import data as pdr

yf.pdr_override()

from datetime import datetime as dt

import yaml


comp = yf.Ticker("ASML")

# %%
info = comp.info
balance_sheet = comp.balance_sheet
income_stmt = comp.income_stmt
financials = comp.financials
cash = comp.cashflow
print(f"balance_sheet: {balance_sheet.shape}")
display(balance_sheet)
print(f"income_stmt: {income_stmt.shape}")
display(income_stmt)
print(f"financials: {financials.shape}")
display(financials)
print(f"cash: {cash.shape}")
display(cash)
# Out:
# balance_sheet: (80, 5)
#                                                        2023-12-31  \
# Treasury Shares Number                                  6162857.0
# Ordinary Shares Number                                393421721.0
# Share Issued                                          399584578.0
# Total Debt                                           4631600000.0
# Tangible Book Value                                  8122100000.0
# Invested Capital                                    18084000000.0
# Working Capital                                      8119200000.0
# Net Tangible Assets                                  8122100000.0
# Common Stock Equity                                 13452400000.0
# Total Capitalization                                18083900000.0
# Total Equity Gross Minority Interest                13452400000.0
# Stockholders Equity                                 13452400000.0
# Gains Losses Not Affecting Retained Earnings          345000000.0
# ...

# %%
comp.news
# Out:
# [{'uuid': 'dcbc6e05-9316-3246-b25c-fb76900a2c6e',
#   'title': '1 Wall Street Analyst Thinks ASML Stock Is Going to $1,000. Is It a Buy Around $872?',
#   'publisher': 'Motley Fool',
#   'link': 'https://finance.yahoo.com/m/dcbc6e05-9316-3246-b25c-fb76900a2c6e/1-wall-street-analyst-thinks.html',
#   'providerPublishTime': 1714227000,
#   'type': 'STORY',
#   'thumbnail': {'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/yyF1CfVD2oFNB84tXztCkA--~B/aD0xNTAwO3c9MjAwMDthcHBpZD15dGFjaHlvbg--/https://media.zenfs.com/en/motleyfool.com/cc14d86a11ef7ffe310bf7d734cb067f',
#      'width': 2000,
#      'height': 1500,
#      'tag': 'original'},
#     {'url': 'https://s.yimg.com/uu/api/res/1.2/4eeNbYcqKS.ZU6vPboFVnA--~B/Zmk9ZmlsbDtoPTE0MDtweW9mZj0wO3c9MTQwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/motleyfool.com/cc14d86a11ef7ffe310bf7d734cb067f',
#      'width': 140,
#      'height': 140,
#      'tag': '140x140'}]},
#   'relatedTickers': ['ASML']},
# ...
